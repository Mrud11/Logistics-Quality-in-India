# %%
import pandas as pd    #1
import numpy as np
import os
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
data= pd.read_csv(r"D:\Users\Mirdula\Downloads\Leads Report 2021 Numeric Data.csv")
data.head(10)
# Out:
#   State wise scores of individual parameters  Quality of Road Infrastructure  \
# 0                                    Gujarat                            3.85
# 1                                    Haryana                            3.68
# 2                                     Punjab                            3.88
# 3                                  TamilNadu                            3.68
# 4                                Maharashtra                            3.40
# 5                               UttarPradesh                            3.47
# 6                                     Odisha                            3.28
# 7                                  Karnataka                            3.51
# 8                              AndhraPradesh                            3.59
# 9                                  Telangana                            3.48
#
#    Quality of Rail Infrastructure  \
# 0                            3.62
# 1                            3.67
# 2                            3.91
# 3                            3.30
# 4                            3.45
# 5                            3.50
# 6                            2.97
# 7                            3.33
# 8                            3.26
# 9                            3.14
#
#    Quality of Multi-Modal Terminal Infrastructure  \
# 0                                            3.79
# 1                                            3.78
# 2                                            3.98
# 3                                            3.49
# 4                                            3.50
# 5                                            3.45
# 6                                            3.28
# 7                                            3.41
# 8                                            3.38
# 9                                            3.47
#
#    Quality of Unimodal Terminal Infrastructure  \
# 0                                         3.50
# 1                                         3.45
# 2                                         3.63
# 3                                         3.18
# 4                                         3.31
# 5                                         3.32
# 6                                         2.91
# 7                                         3.14
# 8                                         2.92
# 9                                         2.94
#
#    Quality ofWarehousing Infrastructure  Quality of Logistics Services  \
# 0                                  3.60                           3.71
# 1                                  3.74                           3.69
# 2                                  3.72                           3.89
# 3                                  3.52                           3.67
# 4                                  3.51                           3.68
# 5                                  3.23                           3.45
# 6                                  2.81                           3.52
# 7                                  3.50                           3.52
# 8                                  3.27                           3.55
# 9                                  3.21                           3.52
#
#    Capability of Logistics Service Providers  \
# 0                                       3.64
# 1                                       3.80
# 2                                       3.87
# 3                                       3.72
# 4                                       3.66
# 5                                       3.47
# 6                                       3.49
# 7                                       3.52
# 8                                       3.50
# 9                                       3.56
#
#    Reasonableness of Road Freight Rates  \
# 0                                  2.36
# 1                                  2.65
# 2                                  2.74
# 3                                  2.54
# 4                                  2.23
# 5                                  2.53
# 6                                  2.07
# 7                                  2.42
# 8                                  2.35
# 9                                  2.31
#
#    Reasonableness of Prices of Terminal Services  \
# 0                                           2.35
# 1                                           2.61
# 2                                           2.75
# 3                                           2.62
# 4                                           2.22
# 5                                           2.53
# 6                                           2.35
# 7                                           2.49
# 8                                           2.47
# 9                                           2.41
#
#    Timeliness of Cargo Delivery (Transportation)   \
# 0                                            3.55
# 1                                            3.70
# 2                                            3.56
# 3                                            3.57
# 4                                            3.53
# 5                                            3.46
# 6                                            3.18
# 7                                            3.56
# 8                                            3.48
# 9                                            3.67
#
#    Timeliness of Cargo Delivery (Terminal Services)  \
# 0                                              3.68
# 1                                              3.71
# 2                                              3.80
# 3                                              3.50
# 4                                              3.51
# 5                                              3.39
# 6                                              3.67
# 7                                              3.49
# 8                                              3.53
# 9                                              3.66
#
#    Availability of Mobile/ Internet Connectivity  \
# 0                                           3.53
# 1                                           3.59
# 2                                           3.89
# 3                                           3.69
# 4                                           3.50
# 5                                           3.53
# 6                                           3.62
# 7                                           3.42
# 8                                           3.60
# 9                                           3.72
#
#    Safety and Security during Transportation  \
# 0                                       3.61
# 1                                       3.62
# 2                                       3.86
# 3                                       3.75
# 4                                       3.54
# 5                                       3.26
# 6                                       3.04
# 7                                       3.70
# 8                                       3.61
# 9                                       3.82
#
#    Safety and Security at Terminals  Extent of Facilitation  \
# 0                              3.72                    3.41
# 1                              3.74                    3.32
# 2                              3.88                    3.31
# 3                              3.74                    3.13
# 4                              3.62                    3.18
# 5                              3.57                    3.22
# 6                              3.51                    3.17
# 7                              3.74                    3.07
# 8                              3.78                    2.95
# 9                              3.92                    2.94
#
#    Ease of Obtaining all Approvals   Efficiency of Regulatory   \
# 0                              3.46                       3.37
# 1                              3.19                       3.38
# 2                              3.28                       3.22
# 3                              3.19                       3.19
# 4                              3.22                       3.19
# 5                              2.95                       3.29
# 6                              3.03                       2.95
# 7                              3.07                       3.07
# 8                              2.94                       2.90
# 9                              2.95                       2.95
#
#    Range scaled Ease of Doing Business ranks  \
# 0                                          2
# 1                                          3
# 2                                          3
# 3                                          2
# 4                                          2
# 5                                          5
# 6                                          1
# 7                                          3
# 8                                          5
# 9                                          5
#
#    Trade Infrastructure for Export Scheme outlay  \
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              5
# 4                                              2
# 5                                              1
# 6                                              1
# 7                                              2
# 8                                              5
# 9                                              1
#
#    States logistics enabling initiatives   \
# 0                                       5
# 1                                       1
# 2                                       3
# 3                                       2
# 4                                       4
# 5                                       5
# 6                                       2
# 7                                       5
# 8                                       3
# 9                                       5
#
#    Assessment of variables of logistics ease  Final Score
# 0                                       3.11         3.66
# 1                                       3.44         3.52
# 2                                       3.78         3.51
# 3                                       3.44         3.36
# 4                                       3.22         3.32
# 5                                       3.89         3.25
# 6                                       3.67         3.20
# 7                                       3.33         3.18
# 8                                       3.22         3.17
# 9                                       3.00         3.14

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 23 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   State wise scores of individual parameters        31 non-null     object
#  1   Quality of Road Infrastructure                    31 non-null     float64
#  2   Quality of Rail Infrastructure                    31 non-null     float64
#  3   Quality of Multi-Modal Terminal Infrastructure    31 non-null     float64
#  4   Quality of Unimodal Terminal Infrastructure       31 non-null     float64
#  5   Quality ofWarehousing Infrastructure              31 non-null     float64
#  6   Quality of Logistics Services                     31 non-null     float64
#  7   Capability of Logistics Service Providers         31 non-null     float64
#  8   Reasonableness of Road Freight Rates              31 non-null     float64
#  9   Reasonableness of Prices of Terminal Services     31 non-null     float64
#  10  Timeliness of Cargo Delivery (Transportation)     31 non-null     float64
#  11  Timeliness of Cargo Delivery (Terminal Services)  31 non-null     float64
#  12  Availability of Mobile/ Internet Connectivity     31 non-null     float64
#  13  Safety and Security during Transportation         31 non-null     float64
#  14  Safety and Security at Terminals                  31 non-null     float64
#  15  Extent of Facilitation                            31 non-null     float64
#  16  Ease of Obtaining all Approvals                   31 non-null     float64
#  17  Efficiency of Regulatory                          31 non-null     float64
#  18  Range scaled Ease of Doing Business ranks         31 non-null     int64
#  19  Trade Infrastructure for Export Scheme outlay     31 non-null     int64
#  20  States logistics enabling initiatives             31 non-null     int64
#  21  Assessment of variables of logistics ease         31 non-null     float64
#  22  Final Score                                       31 non-null     float64
# dtypes: float64(19), int64(3), object(1)
# memory usage: 5.7+ KB

# %%
data.describe()
# Out:
#        Quality of Road Infrastructure  Quality of Rail Infrastructure  \
# count                       31.000000                       31.000000
# mean                         3.041613                        2.881935
# std                          0.603374                        0.661521
# min                          1.930000                        1.500000
# 25%                          2.550000                        2.295000
# 50%                          3.070000                        3.020000
# 75%                          3.495000                        3.355000
# max                          3.880000                        3.910000
#
#        Quality of Multi-Modal Terminal Infrastructure  \
# count                                       31.000000
# mean                                         2.917742
# std                                          0.677828
# min                                          1.530000
# 25%                                          2.420000
# 50%                                          3.130000
# 75%                                          3.430000
# max                                          3.980000
#
#        Quality of Unimodal Terminal Infrastructure  \
# count                                    31.000000
# mean                                      2.822258
# std                                       0.479678
# min                                       1.940000
# 25%                                       2.500000
# 50%                                       2.920000
# 75%                                       3.185000
# max                                       3.630000
#
#        Quality ofWarehousing Infrastructure  Quality of Logistics Services  \
# count                             31.000000                      31.000000
# mean                               2.917742                       3.041613
# std                                0.542714                       0.622613
# min                                1.920000                       1.870000
# 25%                                2.455000                       2.640000
# 50%                                2.900000                       3.230000
# 75%                                3.360000                       3.530000
# max                                3.740000                       3.890000
#
#        Capability of Logistics Service Providers  \
# count                                  31.000000
# mean                                    3.105161
# std                                     0.594849
# min                                     1.780000
# 25%                                     2.705000
# 50%                                     3.380000
# 75%                                     3.515000
# max                                     3.870000
#
#        Reasonableness of Road Freight Rates  \
# count                             31.000000
# mean                               2.156452
# std                                0.446964
# min                                1.270000
# 25%                                1.830000
# 50%                                2.250000
# 75%                                2.495000
# max                                2.780000
#
#        Reasonableness of Prices of Terminal Services  \
# count                                      31.000000
# mean                                        2.239677
# std                                         0.403745
# min                                         1.430000
# 25%                                         1.930000
# 50%                                         2.350000
# 75%                                         2.580000
# max                                         2.750000
#
#        Timeliness of Cargo Delivery (Transportation)   \
# count                                       31.000000
# mean                                         3.016129
# std                                          0.567678
# min                                          1.870000
# 25%                                          2.650000
# 50%                                          3.180000
# 75%                                          3.480000
# max                                          3.700000
#
#        Timeliness of Cargo Delivery (Terminal Services)  \
# count                                         31.000000
# mean                                           3.050645
# std                                            0.581561
# min                                            1.870000
# 25%                                            2.750000
# 50%                                            3.150000
# 75%                                            3.520000
# max                                            3.800000
#
#        Availability of Mobile/ Internet Connectivity  \
# count                                      31.000000
# mean                                        3.101613
# std                                         0.597395
# min                                         2.000000
# 25%                                         2.665000
# 50%                                         3.300000
# 75%                                         3.575000
# max                                         3.890000
#
#        Safety and Security during Transportation  \
# count                                  31.000000
# mean                                    3.114516
# std                                     0.558031
# min                                     2.070000
# 25%                                     2.610000
# 50%                                     3.210000
# 75%                                     3.610000
# max                                     3.880000
#
#        Safety and Security at Terminals  Extent of Facilitation  \
# count                         31.000000               31.000000
# mean                           3.277742                2.745484
# std                            0.513885                0.491500
# min                            2.000000                1.840000
# 25%                            2.880000                2.305000
# 50%                            3.410000                2.940000
# 75%                            3.710000                3.175000
# max                            3.920000                3.410000
#
#        Ease of Obtaining all Approvals   Efficiency of Regulatory   \
# count                         31.000000                  31.000000
# mean                           2.739032                   2.802258
# std                            0.496248                   0.458095
# min                            1.820000                   1.680000
# 25%                            2.320000                   2.455000
# 50%                            2.940000                   2.950000
# 75%                            3.170000                   3.185000
# max                            3.460000                   3.380000
#
#        Range scaled Ease of Doing Business ranks  \
# count                                  31.000000
# mean                                    2.548387
# std                                     1.501970
# min                                     1.000000
# 25%                                     1.000000
# 50%                                     2.000000
# 75%                                     3.000000
# max                                     5.000000
#
#        Trade Infrastructure for Export Scheme outlay  \
# count                                      31.000000
# mean                                        1.967742
# std                                         1.277599
# min                                         1.000000
# 25%                                         1.000000
# 50%                                         1.000000
# 75%                                         3.000000
# max                                         5.000000
#
#        States logistics enabling initiatives   \
# count                               31.000000
# mean                                 3.225806
# std                                  1.257237
# min                                  1.000000
# 25%                                  2.000000
# 50%                                  3.000000
# 75%                                  4.000000
# max                                  5.000000
#
#        Assessment of variables of logistics ease  Final Score
# count                                  31.000000    31.000000
# mean                                    3.121613     2.940323
# std                                     0.505260     0.404149
# min                                     2.220000     2.020000
# 25%                                     2.670000     2.635000
# 50%                                     3.220000     3.060000
# 75%                                     3.500000     3.190000
# max                                     3.890000     3.660000

# %%
data.isnull().sum()
# Out:
# State wise scores of individual parameters          0
# Quality of Road Infrastructure                      0
# Quality of Rail Infrastructure                      0
# Quality of Multi-Modal Terminal Infrastructure      0
# Quality of Unimodal Terminal Infrastructure         0
# Quality ofWarehousing Infrastructure                0
# Quality of Logistics Services                       0
# Capability of Logistics Service Providers           0
# Reasonableness of Road Freight Rates                0
# Reasonableness of Prices of Terminal Services       0
# Timeliness of Cargo Delivery (Transportation)       0
# Timeliness of Cargo Delivery (Terminal Services)    0
# Availability of Mobile/ Internet Connectivity       0
# Safety and Security during Transportation           0
# Safety and Security at Terminals                    0
# Extent of Facilitation                              0
# Ease of Obtaining all Approvals                     0
# Efficiency of Regulatory                            0
# Range scaled Ease of Doing Business ranks           0
# Trade Infrastructure for Export Scheme outlay       0
# States logistics enabling initiatives               0
# Assessment of variables of logistics ease           0
# Final Score                                         0
# dtype: int64

# %%
# Extract the 'state' and 'quality' columns from the DataFrame
states = data['State wise scores of individual parameters'].tolist()
quality = data['Quality of Road Infrastructure'].tolist()

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(states, quality, color='royalblue')
plt.xlabel('State')
plt.ylabel('Quality')
plt.title('Quality by State')

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Extract the 'state' and 'quality' columns from the DataFrame
states = data['State wise scores of individual parameters'].tolist()
quality = data['Quality of Rail Infrastructure'].tolist()

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(states, quality, color='royalblue')
plt.xlabel('State')
plt.ylabel('Quality')
plt.title('Quality by State')

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Extract the 'state' and 'quality' columns from the DataFrame
states = data['State wise scores of individual parameters'].tolist()
quality = data['Quality ofWarehousing Infrastructure'].tolist()

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(states, quality, color='royalblue')
plt.xlabel('State')
plt.ylabel('Quality')
plt.title('Quality by State')

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Extract the 'state' and 'quality' columns from the DataFrame
states = data['State wise scores of individual parameters'].tolist()
quality = data['Timeliness of Cargo Delivery (Transportation) '].tolist()

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(states, quality, color='royalblue')
plt.xlabel('State')
plt.ylabel('Quality')
plt.title('Quality by State')

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Extract the 'state' and 'quality' columns from the DataFrame
states = data['State wise scores of individual parameters'].tolist()
quality = data['Quality of Logistics Services'].tolist()

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(states, quality, color='royalblue')
plt.xlabel('State')
plt.ylabel('Quality')
plt.title('Quality by State')

# Rotate the x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
data_score=data['Final Score']
data=data.drop(['Final Score'],axis=1)
sns.scatterplot(x=data_score,y=data['Quality of Logistics Services'])
# Out:
# <AxesSubplot:xlabel='Final Score', ylabel='Quality of Logistics Services'>
